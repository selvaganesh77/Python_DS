# %%
#Maths
#1
import math
math.sqrt(25)
# Out:
# 5.0

# %%
#2 Cube root
math.cbrt(9)
# Out:
# 2.080083823051904

# %%
#3 factorial
math.factorial(6)
# Out:
# 720

# %%
#4 GCD
math.gcd(30,90)
# Out:
# 30

# %%
#5 LCM
math.lcm(12,18)
# Out:
# 36

# %%
#6 power
math.pow(5, 8)
# Out:
# 390625.0

# %%
#7 absoulte value
import math
num = -1.34
result = math.fabs(num)
print("Original number: ", num)
print("Absolute number: ", result)
# Out:
# Original number:  -1.34
# Absolute number:  1.34

# %%
#8 round
number = 2.5
result = math.ceil(number)
print("original number: ", number)
print("Round up number: ", result)
# Out:
# original number:  2.5
# Round up number:  3

# %%
#9round
number = 25.89
result = math.floor(number)
print("original number: ", number)
print("Round down number: ", result)
# Out:
# original number:  25.89
# Round down number:  25

# %%
#10 round
number = 5.6
result = round(number)
print("original number: ", number)
print("Round  number: ", result)
# Out:
# original number:  5.6
# Round  number:  6

# %%
#11 remaninder
a,b = 25,6
result = math.fmod(a,b)
print("reminder: ",result)
# Out:
# reminder:  1.0

# %%
#12 q nd r
a = 9
b = 3
q,r = divmod(a,b)
print(q)
print(r)
# Out:
# 3
# 0

# %%
#13 sin,cos,tan
x = 45
print(math.sin(x))
print(math.cos(x))
print(math.tan(x))
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %%
#14
degrees = 90
radians = math.radians(degrees)
print(radians)
# Out:
# 1.5707963267948966

# %%
#15
radians = math.pi
degrees = math.degrees(radians)
print(degrees)
# Out:
# 180.0

# %%
base = 10
print(math.log10(base))
# Out:
# 1.0

# %%
#17 natural log
number =  10
result = math.log(number)
print(result)
# Out:
# 2.302585092994046

# %%
#18 e raised
x = 2
result = math.exp(x)
print("Power of x is: ",result)
# Out:
# Power of x is:  7.38905609893065

# %%
#19 value of pi and euler
import math
print("Value of pi:",math.pi)
print("Value of e: ",math.e)
# Out:
# Value of pi: 3.141592653589793
# Value of e:  2.718281828459045

# %%
#20 distance
a, b = ((1,4),(6,8))
result = math.dist(a, b)
print(result)
# Out:
# 6.4031242374328485

# %%
#21 hypotenuse
a, b = 8, 9
result=math.hypot(a, b)
print(result)
# Out:
# 12.041594578792296

# %%
#22 ncr
a, b = 2, 1
result = math.comb(a, b)
print(result)
# Out:
# 2

# %%
#23 permutation
a, b = 5, 2
result = math.perm(a, b)
print(result)
# Out:
# 20

# %%
#24 finite infinte
number = 35
print(math.isfinite(number))
print(math.isinf(number))
print(math.isnan(number))
# Out:
# True
# False
# False

# %%
#25 product
list = [2,4,6,8,10]
result=math.prod(list)
print(result)
# Out:
# 3840

# %%
#26 sum of square root
numbers = [4, 9, 16, 25]
result = sum(math.sqrt(num) for num in numbers)
print(result)
# Out:
# 14.0

# %%
#27 less than or eual
number = 20
result = math.floor(math.sqrt(number))
print(result)
# Out:
# 4

# %%
#28 compound interest
principal = 10000
rate = 5
time = 2
amount = principal * math.pow((1 + rate / 100), time)
compound_interest = amount - principal
print("Amount:", amount)
print("Compound Interest:", compound_interest)
# Out:
# Amount: 11025.0
# Compound Interest: 1025.0

# %%
#29 area and circumference
r = 5
area = math.pi*r**2
circumference = 2*math.pi**2
print("Radius:", r)
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Radius: 5
# Area: 78.53981633974483
# Circumference: 19.739208802178716

# %%
#30 scientific calculator
import math
print("1. Square Root")
print("2. Factorial")
print("3. Log")
print("4. Power")
print("5. GCD")
print("6. LCM")
choice = int(input("Enter choice: "))
if choice == 1:
    n = float(input("Enter number: "))
    print(math.sqrt(n))
elif choice == 2:
    n = int(input("Enter number: "))
    print(math.factorial(n))
elif choice == 3:
    n = float(input("Enter number: "))
    print(math.log(n))
elif choice == 4:
    a = float(input("Base: "))
    b = float(input("Exponent: "))
    print(math.pow(a, b))
elif choice == 5:
    a = int(input("First number: "))
    b = int(input("Second number: "))
    print(math.gcd(a, b))
elif choice == 6:
    a = int(input("First number: "))
    b = int(input("Second number: "))
    print(abs(a * b) // math.gcd(a, b))
else:
    print("Invalid choice")
# Out:
# 1. Square Root
# 2. Factorial
# 3. Log
# 4. Power
# 5. GCD
# 6. LCM
# Enter choice: 4
# Base: 5
# Exponent: 2
# 25.0
